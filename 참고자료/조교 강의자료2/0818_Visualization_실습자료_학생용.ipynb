# %% [markdown]
# # 한화토탈 8월 18일 Visualization 실습자료

# %%
# import libs
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')

# %%
# import dataset
df = pd.read_csv('airbnb_listings.csv', index_col=0)

# %% [markdown]
# ## 1. 전체 데이터 확인

# %% [markdown]
# - Q1. 컬럼 수가 많으니 모든 컬럼을 표시하도록 조정하세요.

# %%
# Q1
# Out:
#      id  host_response_time host_response_rate host_acceptance_rate  \
# 0  2060  a few days or more                22%                  50%
# 1  2595        within a day                87%                  38%
# 2  3831      within an hour                83%                  96%
# 3  5099                 NaN                NaN                  71%
# 4  5114        within a day                50%                  NaN
#
#   host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                 f                  0.0                        0.0
# 1                 f                  6.0                        6.0
# 2                 f                  1.0                        1.0
# 3                 f                  1.0                        1.0
# 4                 f                  3.0                        3.0
#
#                                   host_verifications host_has_profile_pic  \
# ...

# %% [markdown]
# ## 2. 결측치 확인

# %% [markdown]
# - Q2. 각 컬럼의 결측치를 확인하고, 결측치가 많은 순서대로 결측치 비율과 함께 표로 나타내보세요. (결측치 0개인 컬럼은 나타내지 마세요)

# %%
# Q2
# Out:
#                              missing_num  missing_%
# jurisdiction_names                 50781      100.0
# license                            50759       99.9
# square_feet                        50407       99.2
# monthly_price                      46119       90.8
# weekly_price                       45411       89.4
# host_response_time                 19006       37.4
# host_response_rate                 19006       37.4
# security_deposit                   17325       34.1
# host_acceptance_rate               14015       27.6
# review_scores_value                11482       22.6
# review_scores_location             11482       22.6
# review_scores_checkin              11479       22.6
# review_scores_accuracy             11466       22.6
# review_scores_communication        11463       22.6
# review_scores_cleanliness          11452       22.5
# review_scores_rating               11431       22.5
# reviews_per_month                  10453       20.6
# ...

# %% [markdown]
# - Q3. 결측치가 있는 컬럼과 결측치 비율을 보기쉽게 그래프로 나타내 보세요.

# %%
# Q3
plt.figure(figsize = (15,4))

# %% [markdown]
# - Q4. 결측치가 적은 beds 컬럼을 좀 더 자세히 살펴보겠습니다. `beds` 컬럼이 결측치인 데이터의 상위 5개를 출력해주세요.

# %%
# Q4
# Out:
#           id host_response_time host_response_rate host_acceptance_rate  \
# 808   321845                NaN                NaN                  NaN
# 1002  468613                NaN                NaN                  NaN
# 1058  499249                NaN                NaN                   0%
# 1074  505231                NaN                NaN                  NaN
# 1208  587519                NaN                NaN                   0%
#
#      host_is_superhost  host_listings_count  host_total_listings_count  \
# 808                  f                  0.0                        0.0
# 1002                 f                  1.0                        1.0
# 1058                 f                  1.0                        1.0
# 1074                 f                  1.0                        1.0
# 1208                 f                  1.0                        1.0
#
#                                      host_verifications host_has_profile_pic  \
# ...

# %% [markdown]
# ## 3. 범주형 변수 확인

# %% [markdown]
# - 편의를 위해 결측치가 있는 컬럼을 모두 제거하고 진행하겠습니다.

# %%
drop_col = ['jurisdiction_names', 'license', 'square_feet', 'monthly_price',
       'weekly_price', 'host_response_rate', 'host_response_time',
       'security_deposit', 'host_acceptance_rate', 'review_scores_location',
       'review_scores_value', 'review_scores_checkin',
       'review_scores_accuracy', 'review_scores_communication',
       'review_scores_cleanliness', 'review_scores_rating',
       'reviews_per_month', 'beds']
df.drop(columns=drop_col, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50796 entries, 0 to 50795
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                50796 non-null  int64
#  1   host_is_superhost                 50791 non-null  object
#  2   host_listings_count               50791 non-null  float64
#  3   host_total_listings_count         50791 non-null  float64
#  4   host_verifications                50796 non-null  object
#  5   host_has_profile_pic              50791 non-null  object
#  6   host_identity_verified            50791 non-null  object
#  7   neighborhood                      50796 non-null  object
#  8   latitude                          50796 non-null  float64
#  9   longitude                         50796 non-null  float64
#  10  is_location_exact                 50796 non-null  object
# ...

# %% [markdown]
# - Q5. Room Type에는 어떤 것들이 있는지 살펴보겠습니다. `room_type` 컬럼의 종류 별 개수에 대한 그래프를 그려주세요.

# %%
# Q5
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='count'>

# %% [markdown]
# - Q6. 위 그래프의 세로축이 개수가 아닌 비율을 나타내도록 재구성해보세요.

# %%
# Q6

# %% [markdown]
# - Q7. 각 지역 별로 room_type의 비율이 어땠는지 알고 싶습니다. 아래 그래프와 같이 각 지역별로 `room_type`의 개수가 어땠는지 보여주세요.

# %%
# Q7
plt.figure(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='neighborhood', ylabel='count'>

# %% [markdown]
# - Q8. 각 지역별로 가격의 분포가 어떤지 알고 싶습니다. 아래 그래프와 같이 각 지역별로 가격의 분포를 보여주세요.

# %%
# Q8
plt.figure(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='neighborhood', ylabel='price'>

# %% [markdown]
# - Q9. 위 그래프들로부터 알 수 있는 사실은 무엇인가요? 그 이유는 무엇이라고 생각하시나요?

# %%
# Q9

# %% [markdown]
# ## 4. 연속형 변수 확인

# %% [markdown]
# - Q10. 각 방의 수용가능인원의 분포를 알고싶습니다. `accommodates` 컬럼에 대한 히스토그램을 그려주세요.

# %%
# Q10

# %% [markdown]
# - Q11. 각 방의 가격의 분포를 알고 싶습니다. `price` 컹럼에 대한 히스토그램을 그려주세요. 범위는 0~1000까지만 보여주세요.

# %%
# Q11
